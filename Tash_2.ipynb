# %% [markdown]
# <a href="https://colab.research.google.com/github/GopikaDA/Python_coding_challenge/blob/main/Tash_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # String Slicling and Method

# %%
String1 = input("Enter your feedback:")
print(String1)
len(String1)
# Out:
# Enter your feedback:good well
# good well
# 10

# %%
String1 = input("Enter your feedback:")
print(String1)
word_count=len(String1.split())
print("word count:",word_count)
len(String1)
String1.count('data')
# Out:
# Enter your feedback:the data is good
# the data is good
# word count: 4
# 1

# %%
String1 = input("Enter your feedback:")
first_count=String1[0:6:1]
last_count=String1[-6:-1]
Reverse=String1[::-1]
print("First five character:",first_count)
print("last five character:",last_count)
print("Reverse character:",Reverse)
# Out:
# Enter your feedback:good well performnace
# First five character: good w
# last five character: rmnac
# Reverse character: ecanmrofrep llew doog

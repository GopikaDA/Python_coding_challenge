# %% [markdown]
# <a href="https://colab.research.google.com/github/GopikaDA/Python_coding_challenge/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Tuple, Immutable vs Mutable, List Creation

# %% [markdown]
# ## Retail Inventory Manager

# %%
Product_Categorties =('Electorcins','clothing' ,'Stationery')
print("The product categorties are:",Product_Categorties)
# Out:
# The product categorties are: ('Electorcins', 'clothing', 'Stationery')

# %%
product = ['mobile','saree','pen']
print("The Available product are:",product)
# Out:
# The Available product are: ['mobile', 'saree', 'pen']

# %%
new_product = input("enter the new product:")
product.append(new_product)
print("The Update product are:",product)
# Out:
# enter the new product:pencli
# The Update product are: ['mobile', 'saree', 'pen', 'pencli']

# %%
remove_index=int(input("enter the index to remove:"))
product.pop(remove_index)
print("new updated list:",product)
# Out:
# enter the index to remove:3
# new updated list: ['mobile', 'saree', 'pen']

# %%
print("The available product are:",product)
print("the available product categories:",Product_Categorties)
# Out:
# The available product are: ['mobile', 'saree', 'pen']
# the available product categories: ('Electorcins', 'clothing', 'Stationery')

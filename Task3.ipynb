# %% [markdown]
# <a href="https://colab.research.google.com/github/GopikaDA/Python_coding_challenge/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  List Methods and Slicing

# %%
contact = [["Gopika",9489524277,"gopika@gmail.com"],
 ["siva",9876543210,"siva@gmail.com"],
["Tonika",6789055432,"tonika@gmail.com"]]
print(type(contact))
print(contact)
# Out:
# <class 'list'>
# [['Gopika', 9489524277, 'gopika@gmail.com'], ['siva', 9876543210, 'siva@gmail.com'], ['Tonika', 6789055432, 'tonika@gmail.com']]

# %%
name =input("enter the name")
phonenum=int(input("enter the phone number"))
email=input("enter the email")
contact.append([name,phonenum,email])
print(contact)
# Out:
# enter the namenila
# enter the phone number7890654321
# enter the emailnila@gmail.com
# [['Gopika', 9489524277, 'gopika@gmail.com'], ['siva', 9876543210, 'siva@gmail.com'], ['nila', 7890654321, 'nila@gmail.com']]

# %%
contact.pop()
print("After Removing:",contact)
# Out:
# After Removing: [['Gopika', 9489524277, 'gopika@gmail.com'], ['siva', 9876543210, 'siva@gmail.com']]

# %%
contact.sort()
print("After the sort:",contact)
# Out:
# After the sort: [['Gopika', 9489524277, 'gopika@gmail.com'], ['siva', 9876543210, 'siva@gmail.com']]

# %%
len(contact)
# Out:
# 2

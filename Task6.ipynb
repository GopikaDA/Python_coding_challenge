# %% [markdown]
# <a href="https://colab.research.google.com/github/GopikaDA/Python_coding_challenge/blob/main/Task6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operators, Conditional Statements

# %%
# BMI CALCULATOR

weight = int(input("Enter your weight in kg: "))
height = int(input("Enter your height in m:"))

BMI= weight/(height*height)

print("You BMI is:",round(BMI,2))

if BMI > 30:
      print("You are obese")
elif BMI >= 25 and BMI <=30:
      print("You are overweight")
elif BMI >= 18.5 and BMI <=25:
      print("You are normal weight")
else:
      print("You are underweight")
# Out:
# Enter your weight in kg: 100
# Enter your height in m:2
# You BMI is: 25.0
# You are overweight

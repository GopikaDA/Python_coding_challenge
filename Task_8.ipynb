# %% [markdown]
# <a href="https://colab.research.google.com/github/GopikaDA/Python_coding_challenge/blob/main/Task_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # range, for loop, enumerate, list comprehension

# %%
# Employee Hours Report

li=0
for i in range(10):
  num= int(input("ENtetr the score:"))
  li += num
  average= li/10
print(average)
print(li)
# Out:
# ENtetr the score:79
# ENtetr the score:88
# ENtetr the score:87
# ENtetr the score:86
# ENtetr the score:90
# ENtetr the score:88
# ENtetr the score:0
# ENtetr the score:98
# ENtetr the score:77
# ENtetr the score:86
# 77.9
# 779
